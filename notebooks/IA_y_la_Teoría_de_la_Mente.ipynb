# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/Mente-y-M-quina-Repositorio-de-IA-y-Neurociencia/blob/main/notebooks/IA_y_la_Teor%C3%ADa_de_la_Mente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

# Contenido HTML
html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <meta name="description" content="Explora cómo la IA se relaciona con la Teoría de la Mente y los modelos de lenguaje avanzados como GPT-4.">
    <title>IA y la Teoría de la Mente</title>
    <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --primary-color: #007BFF;
            --secondary-color: #0056b3;
            --text-color: #333;
            --background-color: #f5f5f5;
            --accent-color: #004d40;
            --border-color: #ccc;
        }
        body {
            font-family: 'Roboto', Arial, sans-serif;
            line-height: 1.8;
            color: var(--text-color);
            margin: 0;
            padding: 20px;
            background-color: var(--background-color);
        }
        h1, h2 {
            color: var(--accent-color);
            text-align: center;
        }
        h1 {
            font-size: 2.5rem;
            margin-bottom: 20px;
        }
        .index {
            margin-bottom: 20px;
            padding: 15px;
            background: var(--background-color);
            border: 1px solid var(--border-color);
            border-radius: 8px;
        }
        .index h2 {
            margin: 0 0 10px;
        }
        .index ul {
            list-style: none;
            padding: 0;
        }
        .index ul li {
            margin-bottom: 10px;
        }
        .index ul li a {
            text-decoration: none;
            color: var(--primary-color);
            font-weight: bold;
        }
        .index ul li a:hover {
            text-decoration: underline;
        }
        .collapsible {
            background-color: var(--primary-color);
            color: #fff;
            cursor: pointer;
            padding: 10px 20px;
            border: none;
            border-radius: 5px;
            font-size: 1.2rem;
            text-align: left;
            outline: none;
            margin-top: 20px;
            transition: background-color 0.3s;
        }
        .collapsible:hover {
            background-color: var(--secondary-color);
        }
        .collapsible::after {
            content: "▼";
            float: right;
        }
        .collapsible.active::after {
            content: "▲";
        }
        .content {
            max-height: 0;
            overflow: hidden;
            transition: max-height 0.5s ease-in-out;
            margin-top: 10px;
            padding-left: 15px;
            border-left: 3px solid var(--primary-color);
        }
        .button-container {
            text-align: center;
            margin-top: 20px;
        }
        .button {
            display: inline-block;
            padding: 10px 20px;
            font-size: 1rem;
            font-weight: bold;
            color: #fff;
            background-color: var(--primary-color);
            text-decoration: none;
            border-radius: 5px;
            transition: background-color 0.3s;
        }
        .button:hover {
            background-color: var(--secondary-color);
        }
    </style>
</head>
<body>
    <header>
        <h1>IA y la Teoría de la Mente.</h1>
    </header>
        <h2>Material elaborado por Sergio Gevatschnaider</h2>
    <div class="index">
        <h2>Índice</h2>
        <ul>
            <li><a href="#introduccion">Introducción</a></li>
            <li><a href="#relacion-modelos">Relación con los Modelos de Lenguaje</a></li>
            <li><a href="#experimento">El Experimento</a></li>
            <li><a href="#resultados">Resultados</a></li>
            <li><a href="#etica">Implicaciones Éticas y Futuro</a></li>
            <li><a href="#conclusion">Conclusión</a></li>
        </ul>
    </div>

    <main>
        <button type="button" class="collapsible" id="introduccion">Introducción</button>
        <div class="content">
            <p>La Teoría de la Mente (ToM) es una habilidad esencial en los seres humanos que nos permite comprender que otros tienen creencias, deseos e intenciones que pueden diferir de los nuestros. Es un pilar del comportamiento social y de nuestra capacidad para interactuar de manera efectiva en contextos complejos. Esta habilidad suele evaluarse mediante tareas de falsa creencia, que miden la capacidad de entender perspectivas diferentes a la propia.</p>
            <p>Recientemente, un estudio titulado <strong>Evaluating Large Language Models in Theory of Mind Tasks</strong>, realizado por Michal Kosinski, examinó si los modelos de lenguaje de gran tamaño (LLMs, por sus siglas en inglés), como GPT-4, son capaces de realizar tareas relacionadas con la ToM. En este artículo exploramos las pruebas realizadas en el experimento, los resultados obtenidos y lo que estos significan para el avance de la inteligencia artificial.</p>
        </div>

        <button type="button" class="collapsible" id="relacion-modelos">La Teoría de la Mente y su Relación con los Modelos de Lenguaje</button>
        <div class="content">
            <p>En los humanos, la Teoría de la Mente comienza a desarrollarse durante la infancia, generalmente entre los 4 y 5 años. Una de las formas más comunes de evaluarla es a través de las pruebas de falsa creencia, como el test de Sally-Anne, que requiere entender que alguien puede actuar basándose en información incorrecta.</p>
            <p>Los modelos de lenguaje de gran tamaño, como GPT-3 y GPT-4, están diseñados para procesar datos lingüísticos masivos y generar respuestas altamente coherentes. Esto ha llevado a algunos investigadores a plantearse si estos modelos podrían exhibir capacidades similares a la ToM como resultado de su entrenamiento. Este entrenamiento, basado en lenguaje humano, está impregnado de referencias a estados mentales.</p>
        </div>

        <button type="button" class="collapsible" id="experimento">El Experimento: Evaluando la ToM en Modelos de Lenguaje</button>
        <div class="content">
            <p>El estudio implementó una serie de pruebas clásicas y variantes de tareas de falsa creencia para medir si los LLMs podían comprender escenarios que requieren inferencia mental. Estas pruebas incluyeron dos tipos principales: tareas de contenidos inesperados y tareas de transferencia inesperada.</p>
            <h3>1. Tareas de contenidos inesperados</h3>
            <p>En estas pruebas, los modelos debían predecir la creencia de un protagonista frente a un contenido que no coincidía con la apariencia de un objeto. Por ejemplo, un escenario presentaba a Sam encontrando una bolsa etiquetada como "chocolate" que en realidad contenía palomitas. Los modelos tenían que deducir que Sam, al leer la etiqueta, asumiría que la bolsa contenía chocolate.</p>
            <h3>2. Tareas de transferencia inesperada</h3>
            <p>En este caso, los modelos debían razonar sobre un cambio de ubicación que el protagonista no había presenciado. Un ejemplo típico era el siguiente: John colocaba un gato en una canasta antes de salir de la habitación. Mientras estaba fuera, Mark movía al gato a una caja. Al regresar, los modelos debían responder correctamente a preguntas como “¿Dónde buscará John el gato?”, entendiendo que John no había visto el cambio.</p>
            <p>Cada tarea incluyó controles adicionales, como escenarios de creencia verdadera (donde el protagonista tenía acceso a toda la información) y versiones invertidas (donde se intercambiaban etiquetas o ubicaciones iniciales y finales). Estos controles ayudaron a garantizar que los modelos no estuvieran respondiendo de manera arbitraria o basándose únicamente en patrones estadísticos simples.</p>
        </div>

        <button type="button" class="collapsible" id="resultados">Resultados del Experimento</button>
        <div class="content">
            <p>El rendimiento de los modelos varió notablemente según su nivel de complejidad. Los resultados fueron los siguientes:</p>
            <ul>
                <li><strong>GPT-1 y GPT-2XL:</strong> No lograron resolver ninguna de las tareas.</li>
                <li><strong>GPT-3.5-turbo:</strong> Resolvió el 20% de las tareas, un nivel comparable al de niños de 3 años.</li>
                <li><strong>GPT-4:</strong> Mostró un rendimiento notable, resolviendo el 75% de las tareas, lo que equivale al desempeño de un niño de 6 años en pruebas similares.</li>
            </ul>
        </div>

        <button type="button" class="collapsible" id="etica">Implicaciones Éticas y Futuro</button>
        <div class="content">
            <p>Estas capacidades podrían mejorar significativamente la interacción humano-máquina, permitiendo que asistentes virtuales anticipen mejor las necesidades de los usuarios o que se utilicen en contextos educativos y terapéuticos. Por ejemplo, una IA con ToM podría asistir a personas con dificultades sociales a mejorar su interacción interpersonal.</p>
            <p>La capacidad de simular comprensión podría ser utilizada para manipular o engañar a los usuarios, generando desconfianza en estas tecnologías. Además, distinguir entre un comportamiento simulado y una comprensión real será crucial para garantizar que estas herramientas se utilicen de manera ética y segura.</p>
        </div>

        <button type="button" class="collapsible" id="conclusion">Conclusión</button>
        <div class="content">
            <p>El estudio sobre la capacidad de los modelos de lenguaje para realizar tareas relacionadas con la Teoría de la Mente muestra avances impresionantes, especialmente con modelos como GPT-4. Sin embargo, estos resultados no deben confundirse con una verdadera comprensión de los estados mentales, ya que las respuestas de las IA podrían ser simplemente una simulación basada en patrones estadísticos.</p>
            <p>Este avance abre nuevas preguntas sobre cómo integrar estas tecnologías de manera responsable en nuestras vidas.</p>
        </div>

        <div class="button-container">
            <a href="https://arxiv.org/abs/2302.02083?utm_source=chatgpt.com"
               target="_blank"
               class="button"
               rel="noopener noreferrer">
               Evaluating Large Language Models in Theory of Mind Tasks
            </a>
        </div>
    </main>

    <script>
        const collapsibles = document.querySelectorAll(".collapsible");
        collapsibles.forEach(button => {
            button.addEventListener("click", () => {
                button.classList.toggle("active");
                const content = button.nextElementSibling;
                content.style.maxHeight = content.style.maxHeight ? null : content.scrollHeight + "px";
            });
        });
    </script>
</body>
</html>
"""

# Mostrar el HTML en Google Colab
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="description" content="Explora cómo la IA se relaciona con la Teoría de la Mente y los modelos de lenguaje avanzados como GPT-4.">
#     <title>IA y la Teoría de la Mente</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         :root {
#             --primary-color: #007BFF;
#             --secondary-color: #0056b3;
#             --text-color: #333;
#             --background-color: #f5f5f5;
#             --accent-color: #004d40;
#             --border-color: #ccc;
#         }
#         body {
#             font-family: 'Roboto', Arial, sans-serif;
#             line-height: 1.8;
#             color: var(--text-color);
#             margin: 0;
#             padding: 20px;
#             background-color: var(--background-color);
# ...
